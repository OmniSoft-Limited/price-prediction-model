# %%
import pandas as pd

# %%
data = pd.read_csv("../dataset/base.csv")

# %%
data.head()
# Out:
#   projectName  softwareType         industryDomain numUsers targetMarket  \
# 0   Project_1        Mobile                 Travel  '50-100        Local
# 1   Project_2       Desktop                 Travel    '100+         Both
# 2   Project_3       Desktop       Hotel Management     '1-5       Global
# 3   Project_4  Hybrid/Cloud     Content Management    '6-10       Global
# 4   Project_5        Mobile  Restaurant Management    '100+         Both
#
#         targetPlatforms               authentication adminDashboard  \
# 0                   iOS               Enterprise SSO          Basic
# 1                   Web  Multi-factor authentication       Advanced
# 2               Android  Multi-factor authentication          Basic
# 3                   iOS                  Basic login            NaN
# 4  Tablet/Smart Devices                 Social login       Advanced
#
#          ecommerce      contentManagement  ...        extraFeatures  \
# ...

# %%
data.drop("projectName", axis=1, inplace=True)

# %%
data.head()
# Out:
#    softwareType         industryDomain numUsers targetMarket  \
# 0        Mobile                 Travel  '50-100        Local
# 1       Desktop                 Travel    '100+         Both
# 2       Desktop       Hotel Management     '1-5       Global
# 3  Hybrid/Cloud     Content Management    '6-10       Global
# 4        Mobile  Restaurant Management    '100+         Both
#
#         targetPlatforms               authentication adminDashboard  \
# 0                   iOS               Enterprise SSO          Basic
# 1                   Web  Multi-factor authentication       Advanced
# 2               Android  Multi-factor authentication          Basic
# 3                   iOS                  Basic login            NaN
# 4  Tablet/Smart Devices                 Social login       Advanced
#
#          ecommerce      contentManagement communicationFeatures  \
# 0  Payment gateway               Workflow                   NaN
# ...

# %%
data.to_csv("../dataset/base-clean.csv", index=False)

# %%
data["softwareType"]
# Out:
# 0           Mobile
# 1          Desktop
# 2          Desktop
# 3     Hybrid/Cloud
# 4           Mobile
# 5          Desktop
# 6          Desktop
# 7           Mobile
# 8     Hybrid/Cloud
# 9              Web
# 10             Web
# 11          Mobile
# 12             Web
# 13    Hybrid/Cloud
# 14          Mobile
# 15    Hybrid/Cloud
# 16    Hybrid/Cloud
# 17    Hybrid/Cloud
# 18         Desktop
# 19    Hybrid/Cloud
# Name: softwareType, dtype: object

# %%
for softType in data["softwareType"]:
    if softType == 'Hybrid/Cloud':
        print(True)
# Out:
# True
# True
# True
# True
# True
# True
# True

# %%
len(data['softwareType'])
# Out:
# 20

# %%
for i in range(len(data['softwareType'])):
    if data['softwareType'][i] == 'Hybrid/Cloud':
        data['softwareType'][i] = 'Hybrid'

# %%
data.head()
# Out:
#   softwareType         industryDomain numUsers targetMarket  \
# 0       Mobile                 Travel  '50-100        Local
# 1      Desktop                 Travel    '100+         Both
# 2      Desktop       Hotel Management     '1-5       Global
# 3       Hybrid     Content Management    '6-10       Global
# 4       Mobile  Restaurant Management    '100+         Both
#
#         targetPlatforms               authentication adminDashboard  \
# 0                   iOS               Enterprise SSO          Basic
# 1                   Web  Multi-factor authentication       Advanced
# 2               Android  Multi-factor authentication          Basic
# 3                   iOS                  Basic login            NaN
# 4  Tablet/Smart Devices                 Social login       Advanced
#
#          ecommerce      contentManagement communicationFeatures  \
# 0  Payment gateway               Workflow                   NaN
# ...

# %%
numUsers = data["numUsers"]
numUsers.head()
# Out:
# 0    '50-100
# 1      '100+
# 2       '1-5
# 3      '6-10
# 4      '100+
# Name: numUsers, dtype: object

# %%
data["numUsers"] = data["numUsers"].str.strip("' ").str.lstrip("'")

# %%
data.head()
# Out:
#   softwareType         industryDomain numUsers targetMarket  \
# 0       Mobile                 Travel   50-100        Local
# 1      Desktop                 Travel     100+         Both
# 2      Desktop       Hotel Management      1-5       Global
# 3       Hybrid     Content Management     6-10       Global
# 4       Mobile  Restaurant Management     100+         Both
#
#         targetPlatforms               authentication adminDashboard  \
# 0                   iOS               Enterprise SSO          Basic
# 1                   Web  Multi-factor authentication       Advanced
# 2               Android  Multi-factor authentication          Basic
# 3                   iOS                  Basic login            NaN
# 4  Tablet/Smart Devices                 Social login       Advanced
#
#          ecommerce      contentManagement communicationFeatures  \
# 0  Payment gateway               Workflow                   NaN
# ...

# %%
fixedPlatform = []
for item in data['targetPlatforms']:
    if item == 'Tablet/Smart Devices':
        fixedPlatform.append("Both")
    else:
        fixedPlatform.append(item)
fixedPlatform
# Out:
# ['iOS',
#  'Web',
#  'Android',
#  'iOS',
#  'Both',
#  'Android',
#  'Android',
#  'Web',
#  'Desktop',
#  'Desktop',
#  'Both',
#  'Web',
#  'Android',
#  'Android',
#  'Web',
#  'Both',
#  'Both',
#  'Android',
#  'Both',
#  'Android']

# %%
type(data['targetPlatforms'])
# Out:
# pandas.core.series.Series

# %%
fixecPlatformDataframe = pd.DataFrame(fixedPlatform)

# %%
fixecPlatformDataframe
# Out:
#           0
# 0       iOS
# 1       Web
# 2   Android
# 3       iOS
# 4      Both
# 5   Android
# 6   Android
# 7       Web
# 8   Desktop
# 9   Desktop
# 10     Both
# 11      Web
# 12  Android
# 13  Android
# 14      Web
# 15     Both
# 16     Both
# 17  Android
# 18     Both
# 19  Android

# %%
fixecPlatformDataframe.head()
# Out:
#          0
# 0      iOS
# 1      Web
# 2  Android
# 3      iOS
# 4     Both

# %%
data['targetPlatforms'] = fixecPlatformDataframe

# %%
data.head()
# Out:
#   softwareType         industryDomain numUsers targetMarket targetPlatforms  \
# 0       Mobile                 Travel   50-100        Local             iOS
# 1      Desktop                 Travel     100+         Both             Web
# 2      Desktop       Hotel Management      1-5       Global         Android
# 3       Hybrid     Content Management     6-10       Global             iOS
# 4       Mobile  Restaurant Management     100+         Both            Both
#
#                 authentication adminDashboard        ecommerce  \
# 0               Enterprise SSO          Basic  Payment gateway
# 1  Multi-factor authentication       Advanced  Product catalog
# 2  Multi-factor authentication          Basic  Product catalog
# 3                  Basic login            NaN  Cart & Checkout
# 4                 Social login       Advanced              NaN
#
#        contentManagement communicationFeatures        extraFeatures  \
# ...

# %%
fixedAuth = []
for item in data['authentication']:
    if pd.isna(item):  
        fixedAuth.append("Null")
    elif "Multi-factor authentication" in str(item):
        fixedAuth.append("Multi-Factor")
    else:
        fixedAuth.append(item)

fixedAuth
# Out:
# ['Enterprise SSO',
#  'Multi-Factor',
#  'Multi-Factor',
#  'Multi-Factor',
#  'Multi-Factor',
#  'Basic login',
#  'Social login',
#  'Basic login',
#  'Null',
#  'Enterprise SSO',
#  'Multi-Factor',
#  'Multi-Factor',
#  'Basic login',
#  'Social login',
#  'Social login',
#  'Enterprise SSO',
#  'Multi-Factor',
#  'Multi-Factor',
#  'Social login',
#  'Social login']

# %%
fixedAuthDF = pd.DataFrame(fixedAuth)
data['authentication'] = fixedAuthDF
data.head()
# Out:
#   softwareType         industryDomain numUsers targetMarket targetPlatforms  \
# 0       Mobile                 Travel   50-100        Local             iOS
# 1      Desktop                 Travel     100+         Both             Web
# 2      Desktop       Hotel Management      1-5       Global         Android
# 3       Hybrid     Content Management     6-10       Global             iOS
# 4       Mobile  Restaurant Management     100+         Both            Both
#
#    authentication adminDashboard        ecommerce      contentManagement  \
# 0  Enterprise SSO          Basic  Payment gateway               Workflow
# 1    Multi-Factor       Advanced  Product catalog                    NaN
# 2    Multi-Factor          Basic  Product catalog               Workflow
# 3    Multi-Factor            NaN  Cart & Checkout                    NaN
# 4    Multi-Factor       Advanced              NaN  Pages & Media uploads
#
# ...

# %%
data['authentication'] = (
    data['authentication']
    .fillna("None")  # replace NaN with "Null"
    .astype(str)     # ensure string for replace
    .str.replace(r"(?i).*multi-factor.*", "Multi-Factor", regex=True)  # case-insensitive replace
)

# %%
data
# Out:
#    softwareType         industryDomain numUsers targetMarket targetPlatforms  \
# 0        Mobile                 Travel   50-100        Local             iOS
# 1       Desktop                 Travel     100+         Both             Web
# 2       Desktop       Hotel Management      1-5       Global         Android
# 3        Hybrid     Content Management     6-10       Global             iOS
# 4        Mobile  Restaurant Management     100+         Both            Both
# 5       Desktop             E-commerce     100+       Global         Android
# 6       Desktop      Social Networking      1-5       Global         Android
# 7        Mobile             Healthcare      1-5       Global             Web
# 8        Hybrid       Education/EdTech     6-10         Both         Desktop
# 9           Web     Content Management   50-100        Local         Desktop
# 10          Web                FinTech     6-10        Local            Both
# ...

# %%
data.drop('fixedAuth', inplace=True, axis=1)

# %%
data.head()
# Out:
#   softwareType         industryDomain numUsers targetMarket targetPlatforms  \
# 0       Mobile                 Travel   50-100        Local             iOS
# 1      Desktop                 Travel     100+         Both             Web
# 2      Desktop       Hotel Management      1-5       Global         Android
# 3       Hybrid     Content Management     6-10       Global             iOS
# 4       Mobile  Restaurant Management     100+         Both            Both
#
#   adminDashboard        ecommerce      contentManagement  \
# 0          Basic  Payment gateway               Workflow
# 1       Advanced  Product catalog                    NaN
# 2          Basic  Product catalog               Workflow
# 3            NaN  Cart & Checkout                    NaN
# 4       Advanced              NaN  Pages & Media uploads
#
#   communicationFeatures        extraFeatures thirdPartyServices dataMigration  \
# 0                   NaN     Search & Filters              Other            No
# ...

# %%
data['authentication'] = data['fixedAuth']

# %%
pd.isna(data['adminDashboard'][3])
# Out:
# True

# %%
data['adminDashboard'] = data['adminDashboard'].fillna("Null")
data.head()
# Out:
#   softwareType         industryDomain numUsers targetMarket targetPlatforms  \
# 0       Mobile                 Travel   50-100        Local             iOS
# 1      Desktop                 Travel     100+         Both             Web
# 2      Desktop       Hotel Management      1-5       Global         Android
# 3       Hybrid     Content Management     6-10       Global             iOS
# 4       Mobile  Restaurant Management     100+         Both            Both
#
#   adminDashboard        ecommerce      contentManagement  \
# 0          Basic  Payment gateway               Workflow
# 1       Advanced  Product catalog                    NaN
# 2          Basic  Product catalog               Workflow
# 3           Null  Cart & Checkout                    NaN
# 4       Advanced              NaN  Pages & Media uploads
#
#   communicationFeatures        extraFeatures thirdPartyServices dataMigration  \
# 0                   NaN     Search & Filters              Other            No
# ...

# %%
data = data.where(pd.notna(data), None)
data.head()
# Out:
#   softwareType         industryDomain numUsers targetMarket targetPlatforms  \
# 0       Mobile                 Travel   50-100        Local             iOS
# 1      Desktop                 Travel     100+         Both             Web
# 2      Desktop       Hotel Management      1-5       Global         Android
# 3       Hybrid     Content Management     6-10       Global             iOS
# 4       Mobile  Restaurant Management     100+         Both            Both
#
#   adminDashboard        ecommerce      contentManagement  \
# 0          Basic  Payment gateway               Workflow
# 1       Advanced  Product catalog                   None
# 2          Basic  Product catalog               Workflow
# 3           Null  Cart & Checkout                   None
# 4       Advanced             None  Pages & Media uploads
#
#   communicationFeatures        extraFeatures thirdPartyServices dataMigration  \
# 0                  None     Search & Filters              Other            No
# ...

# %%
import numpy as np

# Replace NaN and "Null" with None
data = data.replace({np.nan: None, "Null": None})

# %%
data
# Out:
#    softwareType         industryDomain numUsers targetMarket targetPlatforms  \
# 0        Mobile                 Travel   50-100        Local             iOS
# 1       Desktop                 Travel     100+         Both             Web
# 2       Desktop       Hotel Management      1-5       Global         Android
# 3        Hybrid     Content Management     6-10       Global             iOS
# 4        Mobile  Restaurant Management     100+         Both            Both
# 5       Desktop             E-commerce     100+       Global         Android
# 6       Desktop      Social Networking      1-5       Global         Android
# 7        Mobile             Healthcare      1-5       Global             Web
# 8        Hybrid       Education/EdTech     6-10         Both         Desktop
# 9           Web     Content Management   50-100        Local         Desktop
# 10          Web                FinTech     6-10        Local            Both
# ...

# %%
data.drop('accessibility', axis=1, inplace=True)

# %%
data
# Out:
#    softwareType         industryDomain numUsers targetMarket targetPlatforms  \
# 0        Mobile                 Travel   50-100        Local             iOS
# 1       Desktop                 Travel     100+         Both             Web
# 2       Desktop       Hotel Management      1-5       Global         Android
# 3        Hybrid     Content Management     6-10       Global             iOS
# 4        Mobile  Restaurant Management     100+         Both            Both
# 5       Desktop             E-commerce     100+       Global         Android
# 6       Desktop      Social Networking      1-5       Global         Android
# 7        Mobile             Healthcare      1-5       Global             Web
# 8        Hybrid       Education/EdTech     6-10         Both         Desktop
# 9           Web     Content Management   50-100        Local         Desktop
# 10          Web                FinTech     6-10        Local            Both
# ...
