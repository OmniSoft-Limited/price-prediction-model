# %% [markdown]
# ## Loading the Libs

# %% [markdown]
# We need to load the modules from `preprocessor` package which is a directory ahead from us. For this, we need to change our system path to `..` or a directory up.

# %%
import sys
import os

# Add project root (one level up from notebooks/) to sys.path
sys.path.append(os.path.abspath(".."))

# %%
# Now Let's try to import it
from preprocessor.main import Preprocessor

# %% [markdown]
# ## Data Loading

# %%
data_file = "../notebooks/temp/data_clean.pkl"

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_pickle(data_file)

# %%
data.head()
# Out:
#   softwareType         industryDomain  numUsers targetMarket adminDashboard  \
# 0       Mobile  Restaurant_Management  500-1000       Global          Basic
# 1      Desktop                Fintech     30-50        Local           Null
# 2          Web                Fintech     01-10        Local          Basic
# 3       Mobile       Hotel_Management   100-500         Both       Advanced
# 4      Desktop              Ecommerce     01-10         Both          Basic
#
#   contentManagement          extraFeatures  \
# 0        [Workflow]  [Reporting, Analysis]
# 1        [Workflow]  [Reporting, Analysis]
# 2    [Pages, Media]       [Search, Filter]
# 3        [Workflow]       [Search, Filter]
# 4            [Null]        [File_Handling]
#
#                     thirdPartyService authentication dataMigration uiUxDesign  \
# 0  [Analytics, Payment_Gateway, Mail]   Multi_Factor          Null     Custom
# 1             [Payment_Gateway, Mail]         Social          Null   Advanced
# 2                              [Mail]   Multi_Factor          Null      Basic
# 3             [Mail, Payment_Gateway]         Social          Null     Custom
# 4   [AI_integration, Payment_Gateway]           Null            No     Custom
#
#   performance security availability  timeline_months   Price
# 0      Medium     High       Normal                9  1300.0
# 1        High     Null       Always                3  1050.0
# 2       Basic     Null       Normal               30   310.0
# 3       Basic     Null       Normal                9   750.0
# 4       Basic     Null       Normal                4   920.0

# %% [markdown]
# ## Data Preprocessing

# %%
preprocess = Preprocessor(data)

# %% [markdown]
# Let us now transform the data into numerical quantities

# %%
data = preprocess.transform()

# %%
# Let's see the transformed data
data.head()
# Out:
#    softwareType  industryDomain  numUsers  targetMarket  adminDashboard  \
# 0             3               4     750.0             2               1
# 1             2               9      40.0             1               0
# 2             1               9       5.5             1               1
# 3             3               3     300.0             3               2
# 4             2               1       5.5             3               1
#
#    contentManagement  extraFeatures  thirdPartyService  authentication  \
# 0                1.0            0.0           2.333333               3
# 1                1.0            0.0           3.000000               2
# 2                0.0            0.0           4.000000               3
# 3                1.0            0.0           3.000000               2
# 4                NaN            4.0           1.000000               0
#
#    dataMigration  uiUxDesign  performance  security  availability  \
# 0              0         3.0            2         2           1.0
# 1              0         2.0            3         0           2.0
# 2              0         1.0            1         0           1.0
# 3              0         3.0            1         0           1.0
# 4              1         3.0            1         0           1.0
#
#    timeline_months   Price
# 0                9  1300.0
# 1                3  1050.0
# 2               30   310.0
# 3                9   750.0
# 4                4   920.0

# %% [markdown]
# It seems like there are some cells where data is missing stated as `NaN`. Let us see the count first.

# %%
nan_counts = data.isna().sum()
print(nan_counts)
# Out:
# softwareType          0
# industryDomain        0
# numUsers              0
# targetMarket          0
# adminDashboard        0
# contentManagement    69
# extraFeatures         8
# thirdPartyService     7
# authentication        0
# dataMigration         0
# uiUxDesign            1
# performance           0
# security              0
# availability          5
# timeline_months       0
# Price                 5
# dtype: int64

# %% [markdown]
# As per query, the `contentManagement` column has the most number of missing data. Let's fill the missing data as `0`.

# %%
data = data.fillna(0)

# %% [markdown]
# Let's recheck.

# %%
nan_counts = data.isna().sum()
print(nan_counts)
# Out:
# softwareType         0
# industryDomain       0
# numUsers             0
# targetMarket         0
# adminDashboard       0
# contentManagement    0
# extraFeatures        0
# thirdPartyService    0
# authentication       0
# dataMigration        0
# uiUxDesign           0
# performance          0
# security             0
# availability         0
# timeline_months      0
# Price                0
# dtype: int64

# %%
data.head(10)
# Out:
#    softwareType  industryDomain  numUsers  targetMarket  adminDashboard  \
# 0             3               4     750.0             2               1
# 1             2               9      40.0             1               0
# 2             1               9       5.5             1               1
# 3             3               3     300.0             3               2
# 4             2               1       5.5             3               1
# 5             4               7     300.0             2               3
# 6             4               5      40.0             3               3
# 7             3               2      40.0             3               0
# 8             4               5      20.0             1               0
# 9             2               9     750.0             2               0
#
#    contentManagement  extraFeatures  thirdPartyService  authentication  \
# 0                1.0            0.0           2.333333               3
# 1                1.0            0.0           3.000000               2
# 2                0.0            0.0           4.000000               3
# 3                1.0            0.0           3.000000               2
# 4                0.0            4.0           1.000000               0
# 5                0.0            0.0           2.500000               2
# 6                3.0            2.0           3.000000               3
# 7                3.0            5.0           3.000000               2
# 8                3.0            0.0           1.500000               0
# 9                1.0            0.0           0.000000               0
#
#    dataMigration  uiUxDesign  performance  security  availability  \
# 0              0         3.0            2         2           1.0
# 1              0         2.0            3         0           2.0
# 2              0         1.0            1         0           1.0
# 3              0         3.0            1         0           1.0
# 4              1         3.0            1         0           1.0
# 5              0         3.0            1         0           1.0
# 6              2         2.0            2         0           1.0
# 7              2         1.0            3         1           2.0
# 8              1         3.0            1         2           1.0
# 9              1         2.0            3         1           1.0
#
#    timeline_months   Price
# 0                9  1300.0
# 1                3  1050.0
# 2               30   310.0
# 3                9   750.0
# 4                4   920.0
# 5               36  1630.0
# 6                9  1960.0
# 7               12  1285.0
# 8               24  1100.0
# 9                6   980.0

# %% [markdown]
# ## Saving the Data
# The data seems almost perfect. Let us now save it to a file for the next step.

# %%
final_data_path = "../notebooks/temp/dataset.pkl"
data.to_pickle(final_data_path)
