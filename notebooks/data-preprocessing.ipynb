# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("../dataset/base-clean.csv")
data.head()
# Out:
#   softwareType         industryDomain numUsers targetMarket targetPlatforms  \
# 0       Mobile                 Travel   50-100        Local             iOS
# 1      Desktop                 Travel     100+         Both             Web
# 2      Desktop       Hotel Management      1-5       Global         Android
# 3       Hybrid     Content Management     6-10       Global             iOS
# 4       Mobile  Restaurant Management     100+         Both            Both
#
#   adminDashboard        ecommerce      contentManagement  \
# 0          Basic  Payment gateway               Workflow
# 1       Advanced  Product catalog                    NaN
# 2          Basic  Product catalog               Workflow
# 3            NaN  Cart & Checkout                    NaN
# 4       Advanced              NaN  Pages & Media uploads
#
#   communicationFeatures        extraFeatures thirdPartyServices dataMigration  \
# 0                   NaN     Search & Filters              Other            No
# ...

# %%
from enum import Enum

# %% [markdown]
# | softwareType | industryDomain      | numUsers  | targetMarket | adminDashboard | contentManagement | extraFeatures          | thirdPartyService | authentication | dataMigration | uiUxDesign | performance | security | availability | timeline_months | price   |
# |--------------|--------------------|-----------|--------------|----------------|-------------------|------------------------|------------------|----------------|---------------|------------|-------------|----------|--------------|-----------------|---------|
# | Web          | Ecommerce          | 50-100    | Global       | Basic          | Workflow          | Search_and_Filter      | Analytics        | Multi_Factor   | Yes           | Advanced   | Medium      | High     | Always       | 12              | 92000   |
# | Desktop      | Travel             | 100-500   | Local        | Professional   | Blog              | AI_ML_Module           | Payment_Gateway  | Social         | No            | Custom     | High        | Standard | Normal       | 6               | 135000  |
# | Mobile       | Healthcare         | 500-1000  | Both         | Advanced       | Pages_and_Media   | File_Handling          | Mail             | Basic          | Yes           | Advanced   | High        | High     | Always       | 18              | 168500  |
# | Hybrid       | Edtech             | 1-10      | Global       | Null           | Null              | Null                   | Null             | Null           | No            | Basic      | Basic       | Null     | Normal       | 24              | 45000   |
# | Web          | Fintech            | 30-50     | Both         | Advanced       | Workflow          | Reporting_and_Analysis | Analytics        | Multi_Factor   | Yes           | Custom     | High        | High     | Always       | 9               | 152300  |
# | Desktop      | Hotel_Management   | 10-30     | Local        | Basic          | Blog              | Offline_Mode           | Map              | Social         | Null          | Advanced   | Medium      | Standard | Normal       | 4               | 88000   |
# | Mobile       | Social_Networking  | 100-500   | Global       | Professional   | Pages_and_Media   | AI_ML_Module           | Payment_Gateway  | Multi_Factor   | Yes           | Custom     | High        | High     | Always       | 3               | 210000  |
# | Hybrid       | Restaurant_Management | 50-100 | Both         | Advanced       | Workflow          | Search_and_Filter      | Mail             | Basic          | No            | Advanced   | Medium      | Standard | Normal       | 12              | 97500   |
# | Web          | Content Management | 1-10      | Local        | Null           | Pages_and_Media   | File_Handling          | Null             | Null           | No            | Basic      | Basic       | Null     | Normal       | 6               | 56000   |
# | Desktop      | Others             | 500-1000  | Global       | Professional   | Workflow          | Reporting_and_Analysis | Analytics        | Multi_Factor   | Yes           | Custom     | High        | High     | Always       | 24              | 175000  |
